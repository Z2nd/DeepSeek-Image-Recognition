# %%
from ultralytics import YOLO

model = YOLO("backend/resource/models/electro.pt")  # 载入模型
print(model.names)  # 输出类别名称列表
# Out:
# {0: '1-5-Volt-Battery', 1: '3-3-Volt-Battery', 2: '7-Segment-Display', 3: '9-Volt-Battery', 4: 'Arduino-Mega', 5: 'Arduino-Nano', 6: 'Arduino-Uno', 7: 'BJT-Transistor', 8: 'Bluetooth-Module', 9: 'Breadboard', 10: 'Bridge-Rectifier', 11: 'Buck-Converter', 12: 'Buzzer', 13: 'Capacitor-10mf', 14: 'Capacitor-470mf', 15: 'DC-Motor', 16: 'Diode', 17: 'ESP32', 18: 'ESP32-CAM', 19: 'FT-232-USB-Serial-Module', 20: 'Film-Capacitor', 21: 'Fuse', 22: 'Fuse-Base', 23: 'GSM-Module', 24: 'Gas-Sensor', 25: 'Heat-Sink', 26: 'High-Voltage-Ceramic-Capacitor', 27: 'Humidity-Sensor', 28: 'IC-Base-14-Pin', 29: 'IC-Base-28-Pin', 30: 'IC-Chip', 31: 'IGBT', 32: 'IR-Sensor', 33: 'Inductor', 34: 'Keypad', 35: 'LCD-Display', 36: 'LDR-Sensor', 37: 'LED-Light', 38: 'Low-Voltage-Ceramic-Capacitor', 39: 'MLC-Capacitor', 40: 'MOSFET', 41: 'Motion-Sensor', 42: 'Motor-Driver', 43: 'NTC-Thermistor', 44: 'OLED-Display', 45: 'Pin-Header', 46: 'Push-Switch', 47: 'RFID-Scanner', 48: 'Raindrops-Module', 49: 'Relay-Module', 
# ...
